# %% [markdown]
# Que 1. What is Simple Linear Regression (SLR)? Explain its purpose.
# - Simple Linear Regression (SLR) is a statistical method used to model the relationship between two quantitative variables: one independent variable (predictor) and one dependent variable (response). The purpose of SLR is to estimate how the dependent variable changes as the independent variable changes, and to make predictions or forecasts based on this relationship. The model fits a straight line (regression line) to the data, usually using the least squares method, to minimize the sum of squared differences between observed and predicted values.

# %% [markdown]
# Que 2. What are the key assumptions of Simple Linear Regression?
# - The main assumptions of SLR are:
#
#     - **Linearity:** The relationship between the independent and dependent variable is linear.
#     - **Independence:** Observations are independent of each other.
#     - **Homoscedasticity:** The variance of errors (residuals) is constant across all levels of the independent variable.
#     - **Normality:** The residuals are normally distributed.

# %% [markdown]
# Que 3. Write the mathematical equation for a simple linear regression model and explain each term.
# - The equation for simple linear regression is:
# ŷ = c + mx
# Where:
#     - Ŷ: Predicted value of the dependent variable
#     - c: Intercept (value of ŷ, when x=0)
#     - m: Slope (change in ŷ for a one-unit change in x)
#     - x: Independent variable.

# %% [markdown]
# Que 4. Provide a real-world example where simple linear regression can be applied.
# - A company wants to predict sales based on advertising spend. By collecting data on past advertising budgets and corresponding sales, SLR can be used to model and predict future sales for a given advertising budget.

# %% [markdown]
# Que 5. What is the method of least squares in linear regression?
# - The method of least squares is a technique used to find the regression line that best fits the data. It does this by minimizing the sum of the squared differences (residuals) between the observed values and the values predicted by the regression line. This ensures the line is as close as possible to all data points..

# %% [markdown]
# Que 6. What is Logistic Regression? How does it differ from Linear Regression?
# - Logistic Regression is a supervised learning algorithm used for classification tasks, where the dependent variable is categorical (often binary). Instead of fitting a straight line, logistic regression fits an S-shaped (sigmoid) curve to model the probability that a given input belongs to a particular class.
#
# - Differences:
#     - Output: Linear regression predicts continuous values; logistic regression predicts probabilities for categorical outcomes.
#     - Equation: Linear regression uses a straight line; logistic regression uses the logistic (sigmoid) function.
#     - Use Cases: Linear regression is for regression problems; logistic regression is for classification problems.

# %% [markdown]
# Que 7. Name and briefly describe three common evaluation metrics for regression models.
# - **Mean Squared Error (MSE):** The average of the squared differences between actual and predicted values. Lower MSE indicates better model performance.
# - **Root Mean Squared Error (RMSE):** The square root of MSE, providing error in the same units as the target variable.
# - **R-squared (R2):** Represents the proportion of variance in the dependent variable explained by the independent variable(s). Values range from 0 to 1; higher values indicate a better fit

# %% [markdown]
# Que 8. What is the purpose of the R-squared metric in regression analysis?
# - R-squared (R2) measures how well the regression model explains the variation in the dependent variable. An R2 value of 1 means the model perfectly explains the data, while 0 means it explains none of the variability.

# %%
# Que 9. Write Python code to fit a simple linear regression model using scikit-learn and print the slope and intercept.

from sklearn.linear_model import LinearRegression
import numpy as np
X = np.array([[1], [2], [3], [4], [5]])
y = np.array([2, 4, 5, 4, 5])
model = LinearRegression()
model.fit(X, y)
print("Slope (m):", model.coef_[0])
print("Intercept (c):", model.intercept_)
# Out:
# Slope (m): 0.6
# Intercept (c): 2.2

# %% [markdown]
# Que 10. How do you interpret the coefficients in a simple linear regression model?
# - Intercept (c): The predicted value of the dependent variable when the independent variable is zero.
# - Slope (m): The expected change in the dependent variable for a one-unit increase in the independent variable
